# %%
# %matplotlib inline

# %%
# Import dependencies

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
pyber_ride_df = pd.read_csv('Resources/PyBer_ride_data.csv')
pyber_ride_df
# Out:
#     Month  Avg. Fare ($USD)
# 0     Jan             10.02
# 1     Feb             23.24
# 2     Mar             39.20
# 3   April             35.42
# 4     May             32.34
# 5    June             27.04
# 6    July             43.82
# 7     Aug             10.56
# 8    Sept             11.85
# 9     Oct             27.90
# 10    Nov             20.71
# 11    Dec             20.09

# %%
pyber_ride_df.plot(x='Month', y='Avg. Fare ($USD)')
plt.show()

# %%
# Set x-axis and tick locations.
x_axis = np.arange(len(pyber_ride_df))
tick_locations = [value for value in x_axis]

# Plot the data.
pyber_ride_df.plot(x='Month', y='Avg. Fare ($USD)')
# plt.xticks(tick_locations, pyber_ride_df['Month'])
plt.show()

# %%
pyber_ride_df.plot.bar(x='Month', y='Avg. Fare ($USD)')
plt.show()

# %%
import statistics

test = list(pyber_ride_df['Avg. Fare ($USD)'])

stdev = statistics.stdev(test)

pyber_ride_df.plot.bar(x='Month', y='Avg. Fare ($USD)', color='skyblue', 
                       yerr=stdev, capsize=3, rot=0, figsize=(8,6))

plt.yticks(np.arange(0,51, step=5.0))

plt.show()

# %%
city_df = pd.read_csv('Resources/city_data.csv')
city_df

ride_df = pd.read_csv('Resources/ride_data.csv')
ride_df

# How many columns and rows are there?
    # 120 x 3 for city_df
    # 2375 x 4 for ride_df

# What types of data are present?
    # city_df has city names, driver counts and city type
    # ride_df has city names, dates in dt format, fare amount and ride_id
    
# Is the data readable or does it need to be converted in some way?
    # date column might need potential cleaning, fare might need to be assigned to $
# Out:
#                     city                 date   fare        ride_id
# 0     Lake Jonathanshire  2019-01-14 10:14:22  13.83  5739410935873
# 1     South Michelleport  2019-03-04 18:24:09  30.24  2343912425577
# 2     Port Samanthamouth  2019-02-24 04:29:00  33.44  2005065760003
# 3             Rodneyfort  2019-02-10 23:22:03  23.44  5149245426178
# 4             South Jack  2019-03-06 04:28:35  34.58  3908451377344
# ...                  ...                  ...    ...            ...
# 2370         Michaelberg  2019-04-29 17:04:39  13.38  8550365057598
# 2371     Lake Latoyabury  2019-01-30 00:05:47  20.76  9018727594352
# 2372         North Jaime  2019-02-10 21:03:50  11.11  2781339863778
# 2373        West Heather  2019-05-07 19:22:15  44.94  4256853490277
# 2374          Newtonview  2019-04-25 10:20:13  55.84  9990581345298
#
# [2375 rows x 4 columns]

# %%
city_df.tail(10)
# Out:
#                   city  driver_count   type
# 110         Lake Jamie             4  Rural
# 111    Lake Latoyabury             2  Rural
# 112        North Jaime             1  Rural
# 113  South Marychester             1  Rural
# 114          Garzaport             7  Rural
# 115       Bradshawfurt             7  Rural
# 116       New Ryantown             2  Rural
# 117     Randallchester             9  Rural
# 118        Jessicaport             1  Rural
# 119    South Saramouth             7  Rural
